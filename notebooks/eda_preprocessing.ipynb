# %%
import numpy as nm
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../data/raw/transactions.csv")

# %%
df.shape
# Out:
# (250000, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250000 entries, 0 to 249999
# Data columns (total 17 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   transaction id      250000 non-null  object
#  1   timestamp           250000 non-null  object
#  2   transaction type    250000 non-null  object
#  3   merchant_category   250000 non-null  object
#  4   amount (INR)        250000 non-null  int64
#  5   transaction_status  250000 non-null  object
#  6   sender_age_group    250000 non-null  object
#  7   receiver_age_group  250000 non-null  object
#  8   sender_state        250000 non-null  object
#  9   sender_bank         250000 non-null  object
#  10  receiver_bank       250000 non-null  object
#  11  device_type         250000 non-null  object
#  12  network_type        250000 non-null  object
#  13  fraud_flag          250000 non-null  int64
#  14  hour_of_day         250000 non-null  int64
# ...

# %%
data = df

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250000 entries, 0 to 249999
# Data columns (total 17 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   transaction id      250000 non-null  object
#  1   timestamp           250000 non-null  object
#  2   transaction type    250000 non-null  object
#  3   merchant_category   250000 non-null  object
#  4   amount (INR)        250000 non-null  int64
#  5   transaction_status  250000 non-null  object
#  6   sender_age_group    250000 non-null  object
#  7   receiver_age_group  250000 non-null  object
#  8   sender_state        250000 non-null  object
#  9   sender_bank         250000 non-null  object
#  10  receiver_bank       250000 non-null  object
#  11  device_type         250000 non-null  object
#  12  network_type        250000 non-null  object
#  13  fraud_flag          250000 non-null  int64
#  14  hour_of_day         250000 non-null  int64
# ...

# %%
df['fraud_flag'].value_counts()
# Out:
# fraud_flag
# 0    249520
# 1       480
# Name: count, dtype: int64

# %%
df['fraud_flag'].value_counts(normalize=True) * 100
# Out:
# fraud_flag
# 0    99.808
# 1     0.192
# Name: proportion, dtype: float64

# %%
df.groupby('fraud_flag')['amount (INR)'].describe()
# Out:
#                count         mean          std   min    25%    50%     75%  \
# fraud_flag
# 0           249520.0  1311.395391  1847.210565  10.0  288.0  629.0  1596.0
# 1              480.0  1499.231250  2240.707939  28.0  260.0  618.5  1673.5
#
#                 max
# fraud_flag
# 0           42099.0
# 1           17718.0

# %%
data.head()
# Out:
#   transaction type merchant_category  amount (INR) transaction_status  \
# 0              P2P     Entertainment           868            SUCCESS
# 1              P2M           Grocery          1011            SUCCESS
# 2              P2P           Grocery           477            SUCCESS
# 3              P2P              Fuel          2784            SUCCESS
# 4              P2P          Shopping           990            SUCCESS
#
#   sender_age_group receiver_age_group   sender_state sender_bank  \
# 0            26-35              18-25          Delhi        Axis
# 1            26-35              26-35  Uttar Pradesh       ICICI
# 2            26-35              36-45      Karnataka    Yes Bank
# 3            26-35              26-35          Delhi       ICICI
# 4            26-35              18-25          Delhi        Axis
#
#   receiver_bank device_type network_type  fraud_flag  hour_of_day day_of_week  \
# ...

# %%
data.tail()
# Out:
#        transaction type merchant_category  amount (INR) transaction_status  \
# 249995         Recharge              Food           373            SUCCESS
# 249996              P2P         Utilities          2025            SUCCESS
# 249997              P2P              Food           468            SUCCESS
# 249998         Recharge        Healthcare           284            SUCCESS
# 249999              P2P     Entertainment           531            SUCCESS
#
#        sender_age_group receiver_age_group    sender_state sender_bank  \
# 249995            36-45              26-35       Telangana       ICICI
# 249996            36-45              26-35       Rajasthan        HDFC
# 249997            26-35              18-25     West Bengal       ICICI
# 249998            18-25              36-45  Andhra Pradesh        Axis
# 249999            18-25              26-35       Telangana        Axis
#
#        receiver_bank device_type network_type  fraud_flag  hour_of_day  \
# ...

# %%
data['amount (INR)'].min(), df['amount (INR)'].max()
# Out:
# (np.int64(10), np.int64(42099))

# %%
data['hour_of_day'].unique()
# Out:
# array([15,  6, 13, 10, 19, 22, 18,  9, 20,  0, 12,  7, 17,  4, 21, 16,  1,
#        14,  5,  8, 11, 23,  3,  2])

# %%
data['is_weekend'].unique()
# Out:
# array([0, 1])

# %%
data['fraud_flag'].value_counts()
# Out:
# fraud_flag
# 0    249520
# 1       480
# Name: count, dtype: int64

# %%
data['fraud_flag'].value_counts(normalize=True) * 100
# Out:
# fraud_flag
# 0    99.808
# 1     0.192
# Name: proportion, dtype: float64

# %%
data['fraud_flag'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='fraud_flag'>

# %%
data.isnull().sum()
# Out:
# transaction type      0
# merchant_category     0
# amount (INR)          0
# transaction_status    0
# sender_age_group      0
# receiver_age_group    0
# sender_state          0
# sender_bank           0
# receiver_bank         0
# device_type           0
# network_type          0
# fraud_flag            0
# hour_of_day           0
# day_of_week           0
# is_weekend            0
# dtype: int64

# %%
data.select_dtypes(include='object').apply(
    lambda x: x.str.strip().str.lower().value_counts().head()
)
# Out:
#                transaction type  merchant_category  transaction_status  \
# 18-25                       NaN                NaN                 NaN
# 26-35                       NaN                NaN                 NaN
# 36-45                       NaN                NaN                 NaN
# 3g                          NaN                NaN                 NaN
# 46-55                       NaN                NaN                 NaN
# 4g                          NaN                NaN                 NaN
# 56+                         NaN                NaN                 NaN
# 5g                          NaN                NaN                 NaN
# android                     NaN                NaN                 NaN
# axis                        NaN                NaN                 NaN
# bill payment            37368.0                NaN                 NaN
# delhi                       NaN                NaN                 NaN
# ...

# %%
for col in data.select_dtypes(include='object').columns:
    print(col, data[col].isna().sum())
# Out:
# transaction type 0
# merchant_category 0
# transaction_status 0
# sender_age_group 0
# receiver_age_group 0
# sender_state 0
# sender_bank 0
# receiver_bank 0
# device_type 0
# network_type 0
# day_of_week 0

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data['transaction type'].unique()
# Out:
# array(['P2P', 'P2M', 'Bill Payment', 'Recharge'], dtype=object)

# %%
data['transaction_status'].unique()
# Out:
# array(['SUCCESS', 'FAILED'], dtype=object)

# %%
data['device_type'].unique()
# Out:
# array(['Android', 'iOS', 'Web'], dtype=object)

# %%
data['network_type'].unique()
# Out:
# array(['4G', '5G', 'WiFi', '3G'], dtype=object)

# %%
data['day_of_week'].unique()
# Out:
# array(['Tuesday', 'Thursday', 'Sunday', 'Monday', 'Saturday', 'Wednesday',
#        'Friday'], dtype=object)

# %%
data[data['hour_of_day'] > 23]
# Out:
# Empty DataFrame
# Columns: [transaction type, merchant_category, amount (INR), transaction_status, sender_age_group, receiver_age_group, sender_state, sender_bank, receiver_bank, device_type, network_type, fraud_flag, hour_of_day, day_of_week, is_weekend]
# Index: []

# %%
data[data['hour_of_day'] < 0]
# Out:
# Empty DataFrame
# Columns: [transaction type, merchant_category, amount (INR), transaction_status, sender_age_group, receiver_age_group, sender_state, sender_bank, receiver_bank, device_type, network_type, fraud_flag, hour_of_day, day_of_week, is_weekend]
# Index: []

# %%
data['amount (INR)'].describe()
# Out:
# count    250000.000000
# mean       1311.756036
# std        1848.059224
# min          10.000000
# 25%         288.000000
# 50%         629.000000
# 75%        1596.000000
# max       42099.000000
# Name: amount (INR), dtype: float64

# %%
data['amount (INR)'].hist(bins=50)
# Out:
# <Axes: >

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(x=data['amount (INR)'])
plt.show()

# %%
data['hour_of_day'].value_counts().sort_index()
# Out:
# hour_of_day
# 0      3388
# 1      2244
# 2      1685
# 3      1314
# 4      1247
# 5      1742
# 6      3501
# 7      5630
# 8      8349
# 9     10450
# 10    13904
# 11    16328
# 12    17516
# 13    15038
# 14    11472
# 15    12624
# 16    13992
# 17    18340
# 18    20064
# 19    21232
# 20    18506
# 21    16253
# 22     9364
# 23     5817
# Name: count, dtype: int64

# %%
data['hour_of_day'].value_counts().sort_index().plot(kind='bar')
# Out:
# <Axes: xlabel='hour_of_day'>

# %%
data['is_weekend'].value_counts()
# Out:
# is_weekend
# 0    178663
# 1     71337
# Name: count, dtype: int64

# %%
cat_cols = data.select_dtypes(include='object').columns

# %%
cat_cols
# Out:
# Index(['transaction type', 'merchant_category', 'transaction_status',
#        'sender_age_group', 'receiver_age_group', 'sender_state', 'sender_bank',
#        'receiver_bank', 'device_type', 'network_type', 'day_of_week'],
#       dtype='object')

# %%
data['transaction type'].value_counts()
# Out:
# transaction type
# P2P             112445
# P2M              87660
# Bill Payment     37368
# Recharge         12527
# Name: count, dtype: int64

# %%
data['merchant_category'].value_counts()
# Out:
# merchant_category
# Grocery          49966
# Food             37464
# Shopping         29872
# Fuel             25063
# Other            24828
# Utilities        22338
# Transport        20105
# Entertainment    20103
# Healthcare       12663
# Education         7598
# Name: count, dtype: int64

# %%
data['transaction_status'].value_counts()
# Out:
# transaction_status
# SUCCESS    237624
# FAILED      12376
# Name: count, dtype: int64

# %%
data['sender_age_group'].value_counts()
# Out:
# sender_age_group
# 26-35    87432
# 36-45    62873
# 18-25    62345
# 46-55    24841
# 56+      12509
# Name: count, dtype: int64

# %%
data['receiver_age_group'].value_counts()
# Out:
# receiver_age_group
# 26-35    87864
# 18-25    62611
# 36-45    62151
# 46-55    24823
# 56+      12551
# Name: count, dtype: int64

# %%
data['device_type'].value_counts()
# Out:
# device_type
# Android    187777
# iOS         49613
# Web         12610
# Name: count, dtype: int64

# %%
data['device_type'].value_counts()
# Out:
# device_type
# Android    187777
# iOS         49613
# Web         12610
# Name: count, dtype: int64

# %%
data['network_type'].value_counts()
# Out:
# network_type
# 4G      149813
# 5G       62582
# WiFi     25134
# 3G       12471
# Name: count, dtype: int64

# %%
data['day_of_week'].value_counts()
# Out:
# day_of_week
# Monday       36495
# Sunday       36003
# Wednesday    35700
# Tuesday      35540
# Friday       35496
# Thursday     35432
# Saturday     35334
# Name: count, dtype: int64

# %%
data.groupby('fraud_flag')['amount (INR)'].mean()
# Out:
# fraud_flag
# 0    1311.395391
# 1    1499.231250
# Name: amount (INR), dtype: float64

# %%
data.groupby('fraud_flag')['amount (INR)'].median()
# Out:
# fraud_flag
# 0    629.0
# 1    618.5
# Name: amount (INR), dtype: float64

# %%
pd.crosstab(
    data['transaction type'],
    data['fraud_flag'],
    normalize='index'
)
# Out:
# fraud_flag               0         1
# transaction type
# Bill Payment      0.997939  0.002061
# P2M               0.998095  0.001905
# P2P               0.998168  0.001832
# Recharge          0.997605  0.002395

# %%
pd.crosstab(
    data['merchant_category'],
    data['fraud_flag'],
    normalize='index'
)
# Out:
# fraud_flag                0         1
# merchant_category
# Education          0.997894  0.002106
# Entertainment      0.998010  0.001990
# Food               0.998051  0.001949
# Fuel               0.998085  0.001915
# Grocery            0.998119  0.001881
# Healthcare         0.998342  0.001658
# Other              0.997986  0.002014
# Shopping           0.997924  0.002076
# Transport          0.997861  0.002139
# Utilities          0.998523  0.001477

# %%
pd.crosstab(
    data['transaction_status'],
    data['fraud_flag'],
    normalize='index'
)
# Out:
# fraud_flag                 0         1
# transaction_status
# FAILED              0.998303  0.001697
# SUCCESS             0.998068  0.001932

# %%
pd.crosstab(
    data['sender_age_group'],
    data['fraud_flag'],
    normalize='index'
)
# Out:
# fraud_flag               0         1
# sender_age_group
# 18-25             0.997706  0.002294
# 26-35             0.998136  0.001864
# 36-45             0.998155  0.001845
# 46-55             0.998752  0.001248
# 56+               0.997842  0.002158

# %%
pd.crosstab(
    data['receiver_age_group'],
    data['fraud_flag'],
    normalize='index'
)
# Out:
# fraud_flag                 0         1
# receiver_age_group
# 18-25               0.997892  0.002108
# 26-35               0.998316  0.001684
# 36-45               0.997989  0.002011
# 46-55               0.997704  0.002296
# 56+                 0.998566  0.001434

# %%
pd.crosstab(
    data['device_type'],
    data['fraud_flag'],
    normalize='index'
)
# Out:
# fraud_flag          0         1
# device_type
# Android      0.998062  0.001938
# Web          0.997938  0.002062
# iOS          0.998186  0.001814

# %%
pd.crosstab(
    data['network_type'],
    data['fraud_flag'],
    normalize='index'
)
# Out:
# fraud_flag           0         1
# network_type
# 3G            0.998076  0.001924
# 4G            0.998118  0.001882
# 5G            0.998162  0.001838
# WiFi          0.997653  0.002347

# %%
pd.crosstab(
    data['hour_of_day'],
    data['fraud_flag'],
    normalize='index'
)
# Out:
# fraud_flag          0         1
# hour_of_day
# 0            0.997639  0.002361
# 1            0.997326  0.002674
# 2            0.998220  0.001780
# 3            0.996956  0.003044
# 4            0.999198  0.000802
# 5            0.999426  0.000574
# 6            0.998572  0.001428
# 7            0.997691  0.002309
# 8            0.997844  0.002156
# 9            0.998086  0.001914
# 10           0.998562  0.001438
# 11           0.998346  0.001654
# 12           0.998287  0.001713
# 13           0.998338  0.001662
# 14           0.998169  0.001831
# 15           0.997465  0.002535
# 16           0.997784  0.002216
# 17           0.997983  0.002017
# 18           0.998455  0.001545
# 19           0.997975  0.002025
# 20           0.998001  0.001999
# 21           0.997847  0.002153
# 22           0.997544  0.002456
# 23           0.998453  0.001547

# %%
pd.crosstab(
    data['is_weekend'],
    data['fraud_flag'],
    normalize='index'
)
# Out:
# fraud_flag         0         1
# is_weekend
# 0           0.998114  0.001886
# 1           0.997995  0.002005

# %%
num_cols = ['amount (INR)', 'hour_of_day', 'is_weekend', 'fraud_flag']

# %%
data[num_cols].corr()
# Out:
#               amount (INR)  hour_of_day  is_weekend  fraud_flag
# amount (INR)      1.000000    -0.001604   -0.000653    0.004449
# hour_of_day      -0.001604     1.000000    0.001496    0.001323
# is_weekend       -0.000653     0.001496    1.000000    0.001221
# fraud_flag        0.004449     0.001323    0.001221    1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(6,4))
sns.heatmap(data[num_cols].corr(), annot=True, cmap='coolwarm')
plt.show()

# %%
data.groupby(['hour_of_day', 'fraud_flag'])['amount (INR)'].mean().unstack()
# Out:
# fraud_flag             0            1
# hour_of_day
# 0            1339.665976   601.625000
# 1            1298.685880  1315.166667
# 2            1291.922711   245.333333
# 3            1270.210687  3673.250000
# 4            1340.663724   233.000000
# 5            1225.742677   104.000000
# 6            1318.154462  1753.200000
# 7            1329.216308  1273.692308
# 8            1313.993278  1818.666667
# 9            1320.907383  1597.850000
# 10           1318.597522  1495.250000
# 11           1298.228514  1138.444444
# 12           1335.604369  1730.066667
# 13           1319.934856  1265.480000
# 14           1291.866737  2640.714286
# 15           1319.204574  1460.000000
# 16           1280.264379  1527.548387
# 17           1335.614216  1849.702703
# 18           1311.355963   863.870968
# 19           1328.228373  1853.279070
# 20           1287.330608  1251.486486
# 21           1291.692256  1337.885714
# 22           1287.610855  1010.913043
# ...

# %%
pd.crosstab(
    [data['device_type'], data['network_type']],
    data['fraud_flag'],
    normalize='index'
)
# Out:
# fraud_flag                       0         1
# device_type network_type
# Android     3G            0.997776  0.002224
#             4G            0.998087  0.001913
#             5G            0.998257  0.001743
#             WiFi          0.997562  0.002438
# Web         3G            1.000000  0.000000
#             4G            0.997739  0.002261
#             5G            0.997788  0.002212
#             WiFi          0.998450  0.001550
# iOS         3G            0.998747  0.001253
#             4G            0.998327  0.001673
#             5G            0.997896  0.002104
#             WiFi          0.997791  0.002209

# %%
pd.crosstab(
    [data['sender_bank'], data['receiver_bank']],
    data['fraud_flag'],
    normalize='index'
)
# Out:
# fraud_flag                        0         1
# sender_bank receiver_bank
# Axis        Axis           0.999592  0.000408
#             HDFC           0.997618  0.002382
#             ICICI          0.998981  0.001019
#             IndusInd       0.998423  0.001577
#             Kotak          0.997507  0.002493
# ...                             ...       ...
# Yes Bank    IndusInd       0.998396  0.001604
#             Kotak          0.998499  0.001501
#             PNB            0.997892  0.002108
#             SBI            0.997911  0.002089
#             Yes Bank       0.998017  0.001983
#
# [64 rows x 2 columns]
